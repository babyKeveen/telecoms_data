# %% [markdown]
# # Trip Extraction — Day-by-Day DuckDB
#
# Processes one day at a time to keep memory footprint small and constant.
# Skips dates that already have parquet output (resumable).
#
# ## Trip logic
# - Poll interval: ~450 seconds
# - **Cell handover** (cell_id changes between consecutive polls) = vehicle moving
# - **Stationary** = same cell for >= `STATIONARY_POLLS` consecutive polls
# - **Trip** = continuous run of handovers between two stationary periods
#
# ```
# polls:  [C1] [C2] [C3] [C3] [C3] [C4] [C5] [C5] [C5]
#         move move move same same move move same same
#         |------ TRIP 1 ------|  park  |--- TRIP 2 ---|
# ```

# %%
## Config

import duckdb
import os
from pathlib import Path

DB_PATH   = "/home/jovyan/data/analytics.duckdb"
STAGE_DIR = Path("/home/jovyan/data/stage/trips")
TMP_DIR   = "/home/jovyan/data/tmp"

# How many consecutive same-cell polls = stationary
STATIONARY_POLLS = 2      # 2 x 450s = 15 min

# Minimum cell handovers for a trip to be kept
MIN_HANDOVERS = 2

# Minimum distinct cells visited — filters cell-edge oscillation
MIN_CELLS = 3

MAX_FILES = 30

STAGE_DIR.mkdir(parents=True, exist_ok=True)
os.makedirs(TMP_DIR, exist_ok=True)

print(f"STATIONARY_POLLS={STATIONARY_POLLS}, MIN_HANDOVERS={MIN_HANDOVERS}, MIN_CELLS={MIN_CELLS}")
# Out:
# STATIONARY_POLLS=2, MIN_HANDOVERS=2, MIN_CELLS=3

# %%
## Connect and configure DuckDB

con = duckdb.connect(DB_PATH)
con.execute(f"SET memory_limit='8GB'")
con.execute(f"SET temp_directory='{TMP_DIR}'")
con.execute("SET preserve_insertion_order=false")
con.execute("SET threads=4")

## Rebuild handover_events from parquet
#con.execute("DROP TABLE IF EXISTS handover_events")
#con.execute("""
#    CREATE TABLE handover_events AS
#    SELECT *
#    FROM read_parquet('/home/jovyan/data/stage/handover_events/**/*.parquet')
#""")

summary = con.execute("""
    SELECT
        COUNT(*)                   AS total_rows,
        COUNT(DISTINCT vehicle_id) AS vehicles,
        MIN(event_date)            AS first_date,
        MAX(event_date)            AS last_date,
        COUNT(DISTINCT event_date) AS n_dates
    FROM handover_events
""").df()
print(summary.to_string(index=False))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#  total_rows  vehicles first_date  last_date  n_dates
#   256718325     28416 2025-01-01 2025-05-29      148

# %%
## Get list of dates to process

dates = [
    row[0] for row in
    con.execute("SELECT DISTINCT event_date FROM handover_events ORDER BY event_date").fetchall()
]

print(f"Dates to process: {len(dates)}")
print(f"  First: {dates[0]}")
print(f"  Last:  {dates[-1]}")
# Out:
# Dates to process: 148
#   First: 2025-01-01
#   Last:  2025-05-29

# %%
## Process one day at a time

import time

total_trips = 0
skipped = 0
run_start = time.time()

for i, event_date in enumerate(dates, 1):

    # --- Resumable: skip if parquet already written for this date ---
    out_dir = STAGE_DIR / f"event_date={event_date}"
    if out_dir.exists() and any(out_dir.glob("*.parquet")):
        skipped += 1
        print(f"[{i}/{len(dates)}] SKIP {event_date} (already done)")
        continue

    day_start = time.time()

    # --- Step A: build trips_raw for this date only ---
    con.execute("DROP TABLE IF EXISTS trips_raw")
    con.execute(f"""
    CREATE TABLE trips_raw AS
    WITH
    ranked AS (
        SELECT
            vehicle_id, imsi, event_ts, cell_id, rat, event_date,
            LAG(cell_id) OVER (PARTITION BY vehicle_id ORDER BY event_ts) AS prev_cell,
            CASE
                WHEN cell_id != LAG(cell_id) OVER (PARTITION BY vehicle_id ORDER BY event_ts)
                  OR LAG(cell_id) OVER (PARTITION BY vehicle_id ORDER BY event_ts) IS NULL
                THEN 1 ELSE 0
            END AS cell_changed
        FROM handover_events
        WHERE event_date = '{event_date}'
    ),
    with_run AS (
        SELECT *,
            SUM(cell_changed) OVER (PARTITION BY vehicle_id ORDER BY event_ts) AS cell_run_id
        FROM ranked
    ),
    with_poll_count AS (
        SELECT *,
            ROW_NUMBER() OVER (PARTITION BY vehicle_id, cell_run_id ORDER BY event_ts) AS same_cell_poll_count
        FROM with_run
    ),
    with_stationary AS (
        SELECT *,
            same_cell_poll_count >= {STATIONARY_POLLS} AS stationary,
            LAG(same_cell_poll_count >= {STATIONARY_POLLS})
                OVER (PARTITION BY vehicle_id ORDER BY event_ts) AS prev_stationary
        FROM with_poll_count
    ),
    with_trip_flags AS (
        SELECT *,
            CASE
                WHEN cell_changed = 1
                 AND (prev_stationary OR prev_stationary IS NULL)
                THEN 1 ELSE 0
            END AS trip_start_flag
        FROM with_stationary
    ),
    with_trip_seq AS (
        SELECT *,
            SUM(trip_start_flag) OVER (PARTITION BY vehicle_id ORDER BY event_ts) AS trip_seq,
            NOT stationary AS in_trip
        FROM with_trip_flags
    )
    SELECT *,
        CASE WHEN NOT stationary
            THEN vehicle_id || '_trip_' || LPAD(CAST(trip_seq AS VARCHAR), 3, '0')
            ELSE NULL
        END AS trip_id
    FROM with_trip_seq
    """)

    # --- Step B: aggregate trip summaries ---
    con.execute("DROP TABLE IF EXISTS trip_agg")
    con.execute("""
    CREATE TABLE trip_agg AS
    SELECT
        vehicle_id, imsi, trip_id, trip_seq, event_date,
        MIN(event_ts)                                      AS trip_start,
        MAX(event_ts)                                      AS trip_end,
        COUNT(*)                                           AS n_events,
        COUNT(DISTINCT cell_id)                            AS n_cells,
        SUM(CASE WHEN cell_changed = 1 THEN 1 ELSE 0 END) AS n_handovers,
        FIRST(cell_id ORDER BY event_ts)                   AS first_cell,
        LAST(cell_id ORDER BY event_ts)                    AS last_cell,
        MODE(rat)                                          AS dominant_rat
    FROM trips_raw
    WHERE in_trip
    GROUP BY vehicle_id, imsi, trip_id, trip_seq, event_date
    """)

    # --- Step C: free trips_raw, build cell sequences ---
    con.execute("DROP TABLE IF EXISTS trips_raw")

    con.execute("DROP TABLE IF EXISTS cell_sequences")
    con.execute(f"""
    CREATE TABLE cell_sequences AS
    SELECT
        h.vehicle_id || '_trip_' || LPAD(CAST(t.trip_seq AS VARCHAR), 3, '0') AS trip_id,
        STRING_AGG(h.cell_id, ' -> ' ORDER BY h.event_ts) AS cell_sequence
    FROM handover_events h
    JOIN trip_agg t
        ON  h.vehicle_id = t.vehicle_id
        AND h.event_ts  >= t.trip_start
        AND h.event_ts  <= t.trip_end
    WHERE h.event_date = '{event_date}'
    GROUP BY 1
    """)

    # --- Step D: join and apply filters, write parquet ---
    out_dir.mkdir(parents=True, exist_ok=True)
    out_file = out_dir / "trips.parquet"

    n_trips = con.execute(f"""
    COPY (
        SELECT
            a.vehicle_id, a.imsi, a.event_date, a.trip_id, a.trip_seq,
            a.trip_start, a.trip_end,
            ROUND(DATEDIFF('second', a.trip_start, a.trip_end) / 60.0, 1) AS duration_minutes,
            a.n_handovers, a.n_cells, a.n_events,
            a.first_cell, a.last_cell, a.dominant_rat,
            s.cell_sequence
        FROM trip_agg a
        LEFT JOIN cell_sequences s ON a.trip_id = s.trip_id
        WHERE a.trip_id    IS NOT NULL
          AND a.n_handovers >= {MIN_HANDOVERS}
          AND a.n_cells     >= {MIN_CELLS}
        ORDER BY vehicle_id, trip_start
    ) TO '{out_file}' (FORMAT PARQUET)
    """).fetchone()[0]

    # --- Cleanup working tables ---
    con.execute("DROP TABLE IF EXISTS trip_agg")
    con.execute("DROP TABLE IF EXISTS cell_sequences")

    total_trips += n_trips
    elapsed = time.time() - day_start
    print(f"[{i}/{len(dates)}] {event_date} → {n_trips:,} trips ({elapsed:.1f}s)")

total_elapsed = time.time() - run_start
print(f"\nDone. {len(dates) - skipped} days processed, {skipped} skipped.")
print(f"Total trips written: {total_trips:,}")
print(f"Total runtime: {total_elapsed/60:.1f} min")
# Out:
# [1/148] SKIP 2025-01-01 (already done)
# [2/148] SKIP 2025-01-02 (already done)
# [3/148] SKIP 2025-01-03 (already done)
# [4/148] SKIP 2025-01-04 (already done)
# [5/148] SKIP 2025-01-05 (already done)
# [6/148] SKIP 2025-01-06 (already done)
# [7/148] SKIP 2025-01-07 (already done)
# [8/148] SKIP 2025-01-08 (already done)
# [9/148] SKIP 2025-01-09 (already done)
# [10/148] SKIP 2025-01-10 (already done)
# [11/148] SKIP 2025-01-11 (already done)
# [12/148] SKIP 2025-01-12 (already done)
# [13/148] SKIP 2025-01-13 (already done)
# [14/148] SKIP 2025-01-14 (already done)
# [15/148] SKIP 2025-01-15 (already done)
# [16/148] SKIP 2025-01-17 (already done)
# [17/148] SKIP 2025-01-18 (already done)
# [18/148] SKIP 2025-01-19 (already done)
# [19/148] SKIP 2025-01-20 (already done)
# [20/148] SKIP 2025-01-21 (already done)
# [21/148] SKIP 2025-01-22 (already done)
# [22/148] SKIP 2025-01-23 (already done)
# [23/148] SKIP 2025-01-24 (already done)
# [24/148] SKIP 2025-01-25 (already done)
# [25/148] SKIP 2025-01-26 (already done)
# [26/148] SKIP 2025-01-27 (already done)
# [27/148] SKIP 2025-01-28 (already done)
# [28/148] SKIP 2025-01-29 (already done)
# [29/148] SKIP 2025-01-30 (already done)
# [30/148] SKIP 2025-01-31 (already done)
# [31/148] SKIP 2025-02-01 (already done)
# [32/148] SKIP 2025-02-02 (already done)
# [33/148] SKIP 2025-02-03 (already done)
# [34/148] SKIP 2025-02-04 (already done)
# [35/148] SKIP 2025-02-05 (already done)
# [36/148] SKIP 2025-02-06 (already done)
# [37/148] SKIP 2025-02-07 (already done)
# [38/148] SKIP 2025-02-08 (already done)
# [39/148] SKIP 2025-02-09 (already done)
# [40/148] SKIP 2025-02-10 (already done)
# [41/148] SKIP 2025-02-11 (already done)
# [42/148] SKIP 2025-02-12 (already done)
# [111/148] SKIP 2025-04-22 (already done)
# [112/148] SKIP 2025-04-23 (already done)
# [113/148] SKIP 2025-04-24 (already done)
# [114/148] SKIP 2025-04-25 (already done)
# [115/148] SKIP 2025-04-26 (already done)
# [116/148] SKIP 2025-04-27 (already done)
# [117/148] SKIP 2025-04-28 (already done)
# [118/148] SKIP 2025-04-29 (already done)
# [119/148] SKIP 2025-04-30 (already done)
# [120/148] SKIP 2025-05-01 (already done)
# [121/148] SKIP 2025-05-02 (already done)
# [122/148] SKIP 2025-05-03 (already done)
# [123/148] SKIP 2025-05-04 (already done)
# [124/148] SKIP 2025-05-05 (already done)
# [125/148] SKIP 2025-05-06 (already done)
# [126/148] SKIP 2025-05-07 (already done)
# [127/148] SKIP 2025-05-08 (already done)
# [128/148] SKIP 2025-05-09 (already done)
# [129/148] SKIP 2025-05-10 (already done)
# [130/148] SKIP 2025-05-11 (already done)
# [131/148] SKIP 2025-05-12 (already done)
# [132/148] SKIP 2025-05-13 (already done)
# [133/148] SKIP 2025-05-14 (already done)
# [134/148] SKIP 2025-05-15 (already done)
# [135/148] SKIP 2025-05-16 (already done)
# [136/148] SKIP 2025-05-17 (already done)
# [137/148] SKIP 2025-05-18 (already done)
# [138/148] SKIP 2025-05-19 (already done)
# [139/148] SKIP 2025-05-20 (already done)
# [140/148] SKIP 2025-05-21 (already done)
# [141/148] SKIP 2025-05-22 (already done)
# [142/148] SKIP 2025-05-23 (already done)
# [143/148] SKIP 2025-05-24 (already done)
# [144/148] SKIP 2025-05-25 (already done)
# [145/148] SKIP 2025-05-26 (already done)
# [146/148] SKIP 2025-05-27 (already done)
# [147/148] SKIP 2025-05-28 (already done)
# [148/148] SKIP 2025-05-29 (already done)
#
# Done. 0 days processed, 148 skipped.
# Total trips written: 0
# Total runtime: 0.0 min

# %%
## Register trips table in DuckDB from all parquet files

con.execute("DROP TABLE IF EXISTS trips")
con.execute(f"""
    CREATE TABLE trips AS
    SELECT * FROM read_parquet('{STAGE_DIR}/**/*.parquet')
""")

con.execute("""
    SELECT
        COUNT(*)                       AS n_trips,
        COUNT(DISTINCT vehicle_id)     AS vehicles,
        SUM(n_handovers)               AS total_handovers,
        ROUND(AVG(duration_minutes),1) AS avg_duration_min,
        MIN(event_date)                AS first_date,
        MAX(event_date)                AS last_date
    FROM trips
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    n_trips  vehicles  total_handovers  avg_duration_min first_date  last_date
# 0  4119558     28092       23022134.0              38.9 2025-01-01 2025-05-29

# %%
## Sanity checks

print("=== Top 10 most-active vehicles ===")
con.execute("""
    SELECT vehicle_id,
           COUNT(*)         AS n_trips,
           SUM(n_handovers) AS total_handovers
    FROM trips
    GROUP BY vehicle_id
    ORDER BY total_handovers DESC
    LIMIT 10
""").df()
# Out:
# === Top 10 most-active vehicles ===
#                          vehicle_id  n_trips  total_handovers
# 0  16621DDA5F0E80D3B3045F101C0F59DB     1726          10018.0
# 1  B151A689C48684D8B7F1BFB2CDB322C9      741           9832.0
# 2  79335A7796FD7F70CE3A2A208D9002EC      617           9554.0
# 3  945716E15880434175C488A0073F7AF5     1404           9094.0
# 4  0E08F00770D1BA4078DECD18B585535D     1268           8944.0
# 4  2025-01-18 01:47:33.395              32.4          5.0        3
# 5  2025-01-18 07:18:58.137              80.8         11.0        3
# 6  2025-01-18 08:23:39.114              16.2          3.0        3
# 7  2025-01-18 09:04:04.684              24.3          4.0        3
# 8  2025-01-18 12:34:15.263              64.7          9.0        3
# 9  2025-01-18 13:22:43.477              24.2          4.0        3
# 10 2025-01-18 14:35:29.484              40.4          6.0        3
# 11 2025-01-18 15:23:59.027              32.4          5.0        3
# 12 2025-01-18 17:25:14.533              80.8         11.0        3
# 13 2025-01-18 17:57:34.944              16.2          3.0        3
# 14 2025-01-18 20:39:07.136              96.9         13.0        9
# 15 2025-01-18 21:11:25.955              16.1          3.0        3
# 16 2025-01-18 21:51:49.395              24.3          4.0        3
# 17 2025-01-18 22:56:27.737              24.2          4.0        3
# 18 2025-01-18 23:53:02.291              16.2          3.0        3
# 19 2025-01-19 01:47:50.003              48.5          7.0        3
#
#                                         cell_sequence
# 0        88355082 -> 88355095 -> 88355082 -> 88355297
# 1   88355082 -> 88355297 -> 88355082 -> 88355095 -...
# 2   88355297 -> 88355095 -> 88355297 -> 88355082 -...
# 3                    88355095 -> 88355297 -> 88355081
# 4   88355095 -> 88355297 -> 88355082 -> 88355297 -...
# 5   88355297 -> 88355095 -> 88355082 -> 88355297 -...
# 6                    88355095 -> 88355297 -> 88355082
# 7        88355096 -> 88355297 -> 88355082 -> 88355297
# 8   88355297 -> 88355095 -> 88355082 -> 88355095 -...
# 9        88355095 -> 88355082 -> 88355297 -> 88355082
# 10  88355297 -> 88355095 -> 88355297 -> 88355082 -...
# 11  88355082 -> 88355297 -> 88355082 -> 88355095 -...
# 12  88355082 -> 88355095 -> 88355082 -> 88355297 -...
# 13                   88355095 -> 88355081 -> 88355297
# 14  88355081 -> 88355297 -> 88355096 -> 88355081 -...
# 15                   88355080 -> 88355082 -> 88355297
# 16       88355082 -> 88355096 -> 88355297 -> 88355082
# 17       88355096 -> 88355298 -> 88355082 -> 88355096
# 18                   88355298 -> 88355082 -> 88355297
# 19  88355298 -> 88355096 -> 88355298 -> 88355096 -...

# %%
con.execute(f"""
    SELECT trip_id, trip_start, trip_end, duration_minutes,
           n_handovers, n_cells, cell_sequence
    FROM trips
    WHERE vehicle_id = 'A2FCC9AF8E480E683F655628A3E5E38D'
    ORDER BY trip_start
    LIMIT 20
""").df()
# Out:
#                                       trip_id              trip_start  \
# 0   A2FCC9AF8E480E683F655628A3E5E38D_trip_007 2025-05-15 21:29:19.993
# 1   A2FCC9AF8E480E683F655628A3E5E38D_trip_008 2025-05-15 22:17:36.970
# 2   A2FCC9AF8E480E683F655628A3E5E38D_trip_002 2025-05-16 00:42:40.725
# 3   A2FCC9AF8E480E683F655628A3E5E38D_trip_039 2025-05-17 20:44:33.790
# 4   A2FCC9AF8E480E683F655628A3E5E38D_trip_042 2025-05-17 22:53:29.677
# 5   A2FCC9AF8E480E683F655628A3E5E38D_trip_027 2025-05-19 11:26:01.247
# 6   A2FCC9AF8E480E683F655628A3E5E38D_trip_030 2025-05-19 13:42:54.768
# 7   A2FCC9AF8E480E683F655628A3E5E38D_trip_039 2025-05-19 18:32:40.767
# 14  9852418 -> 182061065 -> 181839639 -> 182035976...
# 15                182311689 -> 182187031 -> 182035976
# 16                182035991 -> 183462499 -> 182061065
# 17                182061079 -> 182035990 -> 182043144
# 18  182035976 -> 243207038 -> 182035984 -> 1820359...
# 19  9852418 -> 243207038 -> 182035990 -> 182187017...

# %%
# Export trips sample to Excel
result = con.execute("""
    SELECT trip_id, trip_start, trip_end, duration_minutes,
           n_handovers, n_cells, cell_sequence
    FROM trips
    WHERE vehicle_id = 'A2FCC9AF8E480E683F655628A3E5E38D'
    ORDER BY trip_start
""").df()

result.to_excel('/home/jovyan/data/stage/trips/A2FCC9AF8E480E683F655628A3E5E38D_20_trips.xlsx', index=False)
print(f"Exported {len(result)} rows")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 10
#       1 # Export trips sample to Excel
#       2 result = con.execute("""
#       3     SELECT trip_id, trip_start, trip_end, duration_minutes,
#       4            n_handovers, n_cells, cell_sequence
#    (...)
#       7     ORDER BY trip_start
#       8 """).df()
# ---> 10 result.to_excel('/home/jovyan/data/stage/trips/A2FCC9AF8E480E683F655628A3E5E38D_20_trips.xlsx', index=False)
#      11 print(f"Exported {len(result)} rows")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/formats/excel.py:946, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     942     need_save = False
#     943 else:
#     944     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     945     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 946     writer = ExcelWriter(  # type: ignore[abstract]
#     947         writer,
#     948         engine=engine,
#     949         storage_options=storage_options,
#     950         engine_kwargs=engine_kwargs,
#     951     )
#     952     need_save = True
#     954 try:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
#      66     engine_kwargs=engine_kwargs,
#      67 )
#      69 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      70 # the file and later write to it
#      71 if "r+" in self._mode:  # Load from existing workbook
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/excel/_base.py:1263, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1259 self._handles = IOHandles(
#    1260     cast(IO[bytes], path), compression={"compression": None}
#    1261 )
#    1262 if not isinstance(path, ExcelWriter):
# -> 1263     self._handles = get_handle(
#    1264         path, mode, storage_options=storage_options, is_text=False
#    1265     )
#    1266 self._cur_sheet = None
#    1268 if date_format is None:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: '/home/jovyan/data/stage/trips/A2FCC9AF8E480E683F655628A3E5E38D_20_trips.xlsx'

# %%
con.execute("""
    SELECT MIN(event_date), MAX(event_date), COUNT(DISTINCT event_date)
    FROM trips
""").df()
