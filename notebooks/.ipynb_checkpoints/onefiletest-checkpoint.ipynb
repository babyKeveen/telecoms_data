# %%
# ONE-FILE TEST CONFIG

IDX_SIM_ID = 5
IDX_CREATION_TS = 2
IDX_COLLECTION_TS = 3
IDX_INSERT_TS = 4
IDX_IMSI = 12
IDX_IMEI = 14
IDX_PLMN = 17
IDX_CELL_ID = 18
IDX_RAT = 23

TEST_FILE = raw_files[0]   # or choose a specific file
print("Testing file:", TEST_FILE)
print("Size MB:", round(TEST_FILE.stat().st_size / (1024**2), 2))
