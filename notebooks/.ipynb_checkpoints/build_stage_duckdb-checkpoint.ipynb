# %% [markdown]
# # Staging — DuckDB Native
#
# Replaces the pandas row-by-row CSV reader with DuckDB's `read_csv` which is
# orders of magnitude faster.
#
# - **Resumable** — skips files already staged (checks for existing parquet)
# - **No destructive reset** — never wipes the stage folder
# - **Controllable** — set `MAX_FILES` to limit how many files are processed

# %%
## Config

import duckdb
import os
from pathlib import Path
import time

RAW_DIR   = Path("/home/jovyan/data/sim/raw/sim_test_decoded/2025/")
STAGE_DIR = Path("/home/jovyan/data/stage/handover_events")
TMP_DIR   = "/home/jovyan/data/tmp"

# Column positions (zero-based) in the raw CSV
# id, test_type, creation_time, collection_time, insert_time, sim_id, ...
COL_EVENT_TS   = '03'   # collection_time
COL_VEHICLE_ID = '05'   # sim_id
COL_IMSI       = '13' # imsi
COL_CELL_ID    = '18' # cell_id
COL_RAT        = '23' # technology (4G/5G)


# Set to an integer to limit files processed (useful for testing)
# Set to None to process all files
MAX_FILES = None

STAGE_DIR.mkdir(parents=True, exist_ok=True)
os.makedirs(TMP_DIR, exist_ok=True)

print(f"RAW_DIR:   {RAW_DIR}")
print(f"STAGE_DIR: {STAGE_DIR}")
print(f"MAX_FILES: {MAX_FILES}")
# Out:
# RAW_DIR:   /home/jovyan/data/sim/raw/sim_test_decoded/2025
# STAGE_DIR: /home/jovyan/data/stage/handover_events
# MAX_FILES: None

# %%
## Connect DuckDB

con = duckdb.connect()  # in-memory — staging doesn't need persistence
con.execute(f"SET temp_directory='{TMP_DIR}'")
con.execute("SET memory_limit='8GB'")
con.execute("SET threads=8")

import os, psutil
print(f"CPUs: {os.cpu_count()}")
print(f"RAM:  {round(psutil.virtual_memory().total / (1024**3), 1)} GB")
# Out:
# CPUs: 24
# RAM:  39.0 GB

# %%
## Find raw files

exts = {".gz", ".csv", ".txt"}
all_files = sorted([
    p for p in RAW_DIR.rglob("*")
    if p.is_file() and p.suffix.lower() in exts
])

raw_files = all_files[:MAX_FILES] if MAX_FILES else all_files

print(f"Total files found: {len(all_files)}")
print(f"Files to consider: {len(raw_files)}")
# Out:
# Total files found: 305
# Files to consider: 305

# %%
## Process files — resumable, DuckDB native

skipped = 0
processed = 0
total_good = 0
total_bad = 0
run_start = time.time()

for i, path in enumerate(raw_files, 1):

    # Derive the expected output path from the filename date
    # e.g. 2025_06_15.txt -> event_date=2025-06-15
    stem = path.stem  # e.g. '2025_06_15'
    event_date = stem.replace('_', '-')  # e.g. '2025-06-15'
    out_dir  = STAGE_DIR / f"event_date={event_date}"
    out_file = out_dir / "stage.parquet"

    # --- Resumable: skip if already staged ---
    if out_file.exists():
        skipped += 1
        print(f"[{i}/{len(raw_files)}] SKIP {path.name}")
        continue

    file_start = time.time()

    try:
        out_dir.mkdir(parents=True, exist_ok=True)

        # DuckDB reads the CSV and writes parquet in one shot
        # column0..columnN maps to zero-based column positions
        result = con.execute(f"""
            COPY (
                SELECT
                    column{COL_VEHICLE_ID}  AS vehicle_id,
                    column{COL_IMSI}        AS imsi,
                    column{COL_EVENT_TS}    AS event_ts,
                    column{COL_CELL_ID}     AS cell_id,
                    column{COL_RAT}         AS rat,
                    '{path.name}'           AS source_file
                FROM read_csv(
                    '{path}',
                    header        = false,
                    ignore_errors = true,
                    compression   = 'auto',
                    delim         = ','
                )
                WHERE column{COL_VEHICLE_ID} IS NOT NULL
                  AND column{COL_CELL_ID}    IS NOT NULL
                  AND column{COL_EVENT_TS}   IS NOT NULL
            ) TO '{out_file}' (FORMAT PARQUET)
        """)

        elapsed = time.time() - file_start
        # Count rows written
        n_rows = con.execute(f"SELECT COUNT(*) FROM read_parquet('{out_file}')").fetchone()[0]
        total_good += n_rows
        processed += 1
        print(f"[{i}/{len(raw_files)}] {path.name} → {n_rows:,} rows ({elapsed:.1f}s)")

    except Exception as e:
        total_bad += 1
        print(f"[{i}/{len(raw_files)}] ERROR {path.name}: {e}")

total_elapsed = time.time() - run_start
print(f"\nDone. {processed} processed, {skipped} skipped, {total_bad} errors")
print(f"Total rows staged: {total_good:,}")
print(f"Total runtime: {total_elapsed/60:.1f} min")
# Out:
# [1/305] 2025_01_01.gz → 179 rows (0.0s)
# [2/305] 2025_01_02.gz → 179 rows (0.0s)
# [3/305] 2025_01_03.gz → 179 rows (0.0s)
# [4/305] 2025_01_04.gz → 179 rows (0.0s)
# [5/305] 2025_01_05.gz → 179 rows (0.0s)
# [6/305] 2025_01_06.gz → 179 rows (0.0s)
# [7/305] 2025_01_07.gz → 171 rows (0.0s)
# [8/305] 2025_01_08.gz → 132 rows (0.0s)
# [9/305] 2025_01_09.gz → 176 rows (0.0s)
# [10/305] 2025_01_10.gz → 179 rows (0.0s)
# [11/305] 2025_01_11.gz → 179 rows (0.0s)
# [12/305] 2025_01_12.gz → 179 rows (0.0s)
# [13/305] 2025_01_13.gz → 179 rows (0.0s)
# [14/305] 2025_01_14.gz → 179 rows (0.0s)
# [15/305] 2025_01_15.gz → 103 rows (0.0s)
# [16/305] ERROR 2025_01_16.gz: Binder Error: Referenced column "column05" not found in FROM clause!
# Candidate bindings: "column0"
#
# LINE 17:                 WHERE column05 IS NOT NULL
#                                ^
# [17/305] 2025_01_17.gz → 584 rows (0.1s)
# [18/305] 2025_01_18.gz → 4,045 rows (0.1s)
# [19/305] 2025_01_19.gz → 3,981 rows (0.1s)
# [20/305] 2025_01_20.gz → 4,085 rows (0.1s)
# [21/305] 2025_01_21.gz → 4,023 rows (0.1s)
# [22/305] 2025_01_22.gz → 3,903 rows (0.1s)
# [23/305] 2025_01_23.gz → 4,088 rows (0.1s)
# [24/305] 2025_01_24.gz → 4,107 rows (0.1s)
# [25/305] 2025_01_25.gz → 4,099 rows (0.1s)
# [26/305] 2025_01_26.gz → 3,992 rows (0.1s)
# [27/305] 2025_01_27.gz → 4,055 rows (0.1s)
# [28/305] 2025_01_28.gz → 4,088 rows (0.1s)
# [29/305] 2025_01_29.gz → 3,993 rows (0.1s)
# [30/305] 2025_01_30.gz → 4,103 rows (0.1s)
# [31/305] 2025_01_31.gz → 4,090 rows (0.1s)
# [32/305] 2025_02_01.gz → 4,094 rows (0.1s)
# [33/305] 2025_02_02.gz → 4,059 rows (0.1s)
# [34/305] 2025_02_03.gz → 51,578 rows (0.4s)
# [35/305] 2025_02_04.gz → 562,031 rows (1.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [36/305] 2025_02_05.gz → 813,841 rows (2.4s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [37/305] 2025_02_06.gz → 827,932 rows (2.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [38/305] 2025_02_07.gz → 825,315 rows (2.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [39/305] 2025_02_08.gz → 823,259 rows (2.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [40/305] 2025_02_09.gz → 823,890 rows (2.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [41/305] 2025_02_10.gz → 824,078 rows (2.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [42/305] 2025_02_11.gz → 818,121 rows (5.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [43/305] 2025_02_12.gz → 815,107 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [44/305] 2025_02_13.gz → 810,618 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [45/305] 2025_02_14.gz → 808,566 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [46/305] 2025_02_15.gz → 819,061 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [47/305] 2025_02_16.gz → 821,915 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [48/305] 2025_02_17.gz → 819,819 rows (3.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [49/305] 2025_02_18.gz → 815,479 rows (3.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [50/305] 2025_02_19.gz → 815,972 rows (2.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [51/305] 2025_02_20.gz → 814,535 rows (3.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [52/305] 2025_02_21.gz → 813,363 rows (5.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [53/305] 2025_02_22.gz → 808,968 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [54/305] 2025_02_23.gz → 808,553 rows (3.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [55/305] 2025_02_24.gz → 810,113 rows (3.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [56/305] 2025_02_25.gz → 807,359 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [57/305] 2025_02_26.gz → 785,465 rows (2.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [58/305] 2025_02_27.gz → 802,786 rows (2.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [59/305] 2025_02_28.gz → 808,735 rows (2.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [60/305] 2025_03_01.gz → 804,522 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [61/305] 2025_03_02.gz → 802,626 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [62/305] 2025_03_03.gz → 801,738 rows (2.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [63/305] 2025_03_04.gz → 1,081,061 rows (7.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [64/305] 2025_03_05.gz → 2,291,502 rows (9.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [65/305] 2025_03_06.gz → 2,293,275 rows (8.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [66/305] 2025_03_07.gz → 2,292,569 rows (8.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [67/305] 2025_03_08.gz → 2,291,079 rows (8.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [68/305] 2025_03_09.gz → 2,284,166 rows (8.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [69/305] 2025_03_10.gz → 2,281,066 rows (8.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [70/305] 2025_03_11.gz → 2,277,736 rows (10.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [71/305] 2025_03_12.gz → 2,275,420 rows (8.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [72/305] 2025_03_13.gz → 2,271,750 rows (8.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [73/305] 2025_03_14.gz → 2,265,215 rows (8.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [74/305] 2025_03_15.gz → 2,261,402 rows (11.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [75/305] 2025_03_16.gz → 2,259,116 rows (8.4s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [76/305] 2025_03_17.gz → 2,257,457 rows (8.2s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [77/305] 2025_03_18.gz → 2,258,045 rows (10.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [78/305] 2025_03_19.gz → 2,247,204 rows (8.3s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [79/305] 2025_03_20.gz → 2,164,953 rows (8.7s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [80/305] 2025_03_21.gz → 2,165,841 rows (8.3s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [81/305] 2025_03_22.gz → 2,162,486 rows (10.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [82/305] 2025_03_23.gz → 2,160,625 rows (7.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [83/305] 2025_03_24.gz → 2,159,465 rows (7.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [84/305] 2025_03_25.gz → 2,163,279 rows (8.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [85/305] 2025_03_26.gz → 2,163,904 rows (11.3s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [86/305] 2025_03_27.gz → 2,164,648 rows (8.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [87/305] 2025_03_28.gz → 2,168,761 rows (8.2s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [88/305] 2025_03_29.gz → 2,169,210 rows (10.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [89/305] 2025_03_30.gz → 2,169,063 rows (8.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [90/305] 2025_03_31.gz → 2,165,925 rows (8.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [91/305] 2025_04_01.gz → 2,165,313 rows (7.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [92/305] 2025_04_02.gz → 2,172,959 rows (10.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [93/305] 2025_04_03.gz → 2,157,407 rows (8.2s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [94/305] 2025_04_04.gz → 2,290,270 rows (8.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [95/305] 2025_04_05.gz → 2,666,543 rows (9.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [96/305] 2025_04_06.gz → 2,664,837 rows (12.4s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [97/305] 2025_04_07.gz → 2,664,833 rows (9.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [98/305] 2025_04_08.gz → 2,664,499 rows (9.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [99/305] 2025_04_09.gz → 2,659,544 rows (13.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [100/305] 2025_04_10.gz → 2,661,489 rows (10.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [101/305] 2025_04_11.gz → 2,664,603 rows (10.4s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [102/305] 2025_04_12.gz → 2,667,438 rows (10.4s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [103/305] 2025_04_13.gz → 2,665,502 rows (10.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [104/305] 2025_04_14.gz → 2,663,130 rows (10.7s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [105/305] 2025_04_15.gz → 2,659,895 rows (9.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [106/305] 2025_04_16.gz → 2,649,285 rows (9.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [107/305] 2025_04_17.gz → 2,629,080 rows (12.2s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [108/305] 2025_04_18.gz → 2,629,322 rows (10.4s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [109/305] 2025_04_19.gz → 2,628,009 rows (9.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [110/305] 2025_04_20.gz → 2,629,959 rows (9.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [111/305] 2025_04_21.gz → 2,629,180 rows (12.3s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [112/305] 2025_04_22.gz → 2,627,200 rows (10.0s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [113/305] 2025_04_23.gz → 2,624,723 rows (10.2s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [114/305] 2025_04_24.gz → 2,627,415 rows (12.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [115/305] 2025_04_25.gz → 2,630,388 rows (9.7s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [116/305] 2025_04_26.gz → 2,627,934 rows (14.2s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [117/305] 2025_04_27.gz → 2,629,651 rows (9.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [118/305] 2025_04_28.gz → 2,624,018 rows (9.6s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [119/305] 2025_04_29.gz → 2,622,292 rows (9.8s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [120/305] 2025_04_30.gz → 2,619,672 rows (12.9s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [121/305] 2025_05_01.gz → 2,618,717 rows (11.1s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [122/305] 2025_05_02.gz → 2,614,845 rows (12.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [123/305] 2025_05_03.gz → 2,612,645 rows (10.5s)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [124/305] ERROR 2025_05_04.gz: KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /opt/conda/lib/python3.11/site-packages/traitlets/traitlets.py(739): __set__
#   /tmp/ipykernel_2540/3247748607.py(31): <module>
#   /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3526): run_code
#   /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3466): run_ast_nodes
#   /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3284): run_cell_async
#   /opt/conda/lib/python3.11/site-packages/IPython/core/async_helpers.py(129): _pseudo_sync_runner
#   /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3079): _run_cell
#   /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3024): run_cell
#   /opt/conda/lib/python3.11/site-packages/ipykernel/zmqshell.py(546): run_cell
#   /opt/conda/lib/python3.11/site-packages/ipykernel/ipkernel.py(422): do_execute
#   /opt/conda/lib/python3.11/site-packages/ipykernel/kernelbase.py(740): execute_request
#   /opt/conda/lib/python3.11/site-packages/ipykernel/kernelbase.py(412): dispatch_shell
#   /opt/conda/lib/python3.11/site-packages/ipykernel/kernelbase.py(505): process_one
#   /opt/conda/lib/python3.11/site-packages/ipykernel/kernelbase.py(516): dispatch_queue
#   /opt/conda/lib/python3.11/asyncio/events.py(80): _run
#   /opt/conda/lib/python3.11/asyncio/base_events.py(1922): _run_once
#   /opt/conda/lib/python3.11/asyncio/base_events.py(607): run_forever
#   /opt/conda/lib/python3.11/site-packages/tornado/platform/asyncio.py(195): start
#   /opt/conda/lib/python3.11/site-packages/ipykernel/kernelapp.py(736): start
#   /opt/conda/lib/python3.11/site-packages/traitlets/config/application.py(1053): launch_instance
#   /opt/conda/lib/python3.11/site-packages/ipykernel_launcher.py(17): <module>
#   <frozen runpy>(88): _run_code
#   <frozen runpy>(198): _run_module_as_main
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# [125/305] 2025_05_05.gz → 2,614,620 rows (12.0s)

# %%
## Verify — check a sample parquet file

sample_files = list(STAGE_DIR.rglob("*.parquet"))
print(f"Parquet files on disk: {len(sample_files)}")

con.execute(f"""
    SELECT *
    FROM read_parquet('{sample_files[0]}')
    LIMIT 3
""").df()

# %%
## Register handover_events in analytics DuckDB

analytics = duckdb.connect("/home/jovyan/data/analytics.duckdb")
analytics.execute("SET memory_limit='8GB'")

analytics.execute("DROP TABLE IF EXISTS handover_events")
analytics.execute(f"""
    CREATE TABLE handover_events AS
    SELECT
        vehicle_id,
        imsi,
        event_ts,
        cell_id,
        rat,
        source_file,
        CAST(event_ts AS DATE) AS event_date
    FROM read_parquet('{STAGE_DIR}/**/*.parquet')
    WHERE vehicle_id IS NOT NULL
      AND cell_id    IS NOT NULL
      AND event_ts   IS NOT NULL
""")

analytics.execute("""
    SELECT
        COUNT(*)                   AS total_rows,
        COUNT(DISTINCT vehicle_id) AS vehicles,
        COUNT(DISTINCT cell_id)    AS cells,
        MIN(event_ts)              AS min_event,
        MAX(event_ts)              AS max_event
    FROM handover_events
""").df()
