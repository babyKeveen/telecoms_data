# %%
# ONE-FILE TEST CONFIG
import shutil
from pathlib import Path

IDX_SIM_ID = 5
IDX_CREATION_TS = 2
IDX_COLLECTION_TS = 3
IDX_INSERT_TS = 4
IDX_IMSI = 12
IDX_IMEI = 14
IDX_PLMN = 17
IDX_CELL_ID = 18
IDX_RAT = 23

TEST_FILE =Path('/home/jovyan/data/sim/raw/sim_test_decoded/2025/2025_06_15.txt')   # or choose a specific file
print("Testing file:", TEST_FILE)
print("Size MB:", round(TEST_FILE.stat().st_size / (1024**2), 2))
# Out:
# Testing file: /home/jovyan/data/sim/raw/sim_test_decoded/2025/2025_06_15.txt
# Size MB: 2063.1
